# %%
# %pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\python311\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\python311\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

query = 'posts' # "site:https://www.ucvtscampuschronicle.com+posts&num=80"  # Modify the query as needed
url = f"https://www.google.com/search?q={query}"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers, timeout=1)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
else:
    print(f"Failed to fetch URL: {url}")
    print(f"Status code: {response.status_code}")

    # load from results file
    with open('results.txt', 'r') as f:
        soup = BeautifulSoup(f.read(), 'html.parser')
        print("Loaded from file")
# Out:
# Failed to fetch URL: https://www.google.com/search?q=posts
# Status code: 429
# Loaded from file

# %%
all_urls = [a['href'] for a in soup.find_all('a', href=True)]
campus_urls = [url for url in all_urls if 'https://www.ucvtscampuschronicle.com/single-post/' in url]
campus_urls
# Out:
# ['https://www.ucvtscampuschronicle.com/single-post/practicing-self-love',
#  'https://www.ucvtscampuschronicle.com/single-post/chatgpt-s-meteoric-rise-what-does-the-future-of-communication-look-like',
#  'https://www.ucvtscampuschronicle.com/single-post/how-tiktok-is-quickening-the-fashion-trend-cycle',
#  'https://www.ucvtscampuschronicle.com/single-post/how-shows-and-movies-are-filming-during-the-pandemic',
#  'https://www.ucvtscampuschronicle.com/single-post/the-fashion-industry-s-not-so-secret-impact',
#  'https://www.ucvtscampuschronicle.com/single-post/the-problem-with-spotify-wrapped',
#  'https://www.ucvtscampuschronicle.com/single-post/misogyny-in-everyday-life',
#  'https://www.ucvtscampuschronicle.com/single-post/open-letter-submission',
#  'https://www.ucvtscampuschronicle.com/single-post/5-fruits-that-are-good-for-you',
#  'https://www.ucvtscampuschronicle.com/single-post/stage-fright-a-monologue',
#  'https://www.ucvtscampuschronicle.com/single-post/why-rising-gas-prices-are-important',
#  'https://www.ucvtscampuschronicle.com/single-post/behind-the-curtain-a-sneak-peak-at-the-process-of-bringing-a-play-to-life',
#  'https://www.ucvtscampuschronicle.com/single-post/how-a-person-s-outlook-on-death-affects-their-outlook-on-life',
#  'https://www.ucvtscampuschronicle.com/single-post/restaurant-reviews-around-union-county',
#  'https://www.ucvtscampuschronicle.com/single-post/track-5-union-county-s-favorite-cup-o-joe',
#  'https://www.ucvtscampuschronicle.com/single-post/the-lack-of-innovation-at-apple',
#  'https://www.ucvtscampuschronicle.com/single-post/climate-change-the-floods-in-pakistan',
#  'https://www.ucvtscampuschronicle.com/single-post/album-review-after-the-gold-rush-by-neil-young',
#  'https://www.ucvtscampuschronicle.com/single-post/open-veins-of-latin-america-yea-or-nay-book-review',
#  'https://www.ucvtscampuschronicle.com/single-post/boutiques-around-union-county-millburn-edition',
#  'https://www.ucvtscampuschronicle.com/single-post/2019/11/03/concert-review-the-regrettes-at-bowery-ballroom',
#  'https://www.ucvtscampuschronicle.com/single-post/humans-on-mars-spacex-s-quest-to-colonize-the-red-planet',
#  'https://www.ucvtscampuschronicle.com/single-post/your-brain-on-the-holidays',
#  'https://www.ucvtscampuschronicle.com/single-post/young-voters-and-midterm-elections-what-s-the-connection',
#  'https://www.ucvtscampuschronicle.com/single-post/2019/02/14/outsourcing-to-china-is-depleting-the-united-states-gdp',
#  'https://www.ucvtscampuschronicle.com/single-post/the-science-behind-the-shot-how-vaccines-work',
#  'https://www.ucvtscampuschronicle.com/single-post/the-greatness-of-breaking-bad',
#  'https://www.ucvtscampuschronicle.com/single-post/2020/05/23/interview-with-mrs-mansfield-smith-principal-of-magnet-high-school',
#  'https://www.ucvtscampuschronicle.com/single-post/how-countries-have-handled-coronavirus',
#  'https://www.ucvtscampuschronicle.com/single-post/julian-assange-s-extradition-ruling',
#  'https://www.ucvtscampuschronicle.com/single-post/2020/05/17/a-book-review-sans-spoilers-never-let-me-go-by-kazuo-ishiguro',
#  'https://www.ucvtscampuschronicle.com/single-post/recap-of-the-2022-mlb-season',
#  'https://www.ucvtscampuschronicle.com/single-post/the-fast-fashion-industry-an-ethical-overview',
#  'https://www.ucvtscampuschronicle.com/single-post/casper-ruud-tennis-next-star',
#  'https://www.ucvtscampuschronicle.com/single-post/why-you-should-watch-she-ra-and-the-princesses-of-power',
#  'https://www.ucvtscampuschronicle.com/single-post/op-ed-fast-fashion-better-alternatives',
#  'https://www.ucvtscampuschronicle.com/single-post/2019/11/03/greta-thunberg-leads-global-climate-strike',
#  'https://www.ucvtscampuschronicle.com/single-post/at-the-brink-of-an-artificial-intelligence-cold-war',
#  'https://www.ucvtscampuschronicle.com/single-post/craziest-places-on-earth-that-look-fictional-but-aren-t',
#  'https://www.ucvtscampuschronicle.com/single-post/2019/11/03/la-esperantisto-and-the-beauty-of-esperanto',
#  'https://www.ucvtscampuschronicle.com/single-post/covering-the-transfer-window-of-the-european-leagues-soccer',
#  'https://www.ucvtscampuschronicle.com/single-post/don-t-burn-out-in-high-school',
#  'https://www.ucvtscampuschronicle.com/single-post/2019/05/21/death-by-potatoes-could-mark-watney-really-have-survived-in-the-martian',
#  'https://www.ucvtscampuschronicle.com/single-post/revolutionary-progress-in-curing-alzheimer-s-disease',
#  'https://www.ucvtscampuschronicle.com/single-post/exercise-during-the-quarantine-its-importance-and-how-to-implement-it-in-your-own-life',
#  'https://www.ucvtscampuschronicle.com/single-post/how-the-theft-of-the-mona-lisa-launched-an-ordinary-painting-to-superstar-status',
#  'https://www.ucvtscampuschronicle.com/single-post/harry-styles-redefining-masculinity',
#  'https://www.ucvtscampuschronicle.com/single-post/the-nobel-prize-a-high-honor',
#  'https://www.ucvtscampuschronicle.com/single-post/hybrid-vs-in-person-learning-at-ucvts',
#  'https://www.ucvtscampuschronicle.com/single-post/album-review-nectar-by-joji',
#  'https://www.ucvtscampuschronicle.com/single-post/grey-s-anatomy-how-is-it-still-running',
#  'https://www.ucvtscampuschronicle.com/single-post/modern-rejection-of-the-gender-binary',
#  'https://www.ucvtscampuschronicle.com/single-post/lionel-messi-cristiano-ronaldo-football-s-greatest-ever-players',
#  'https://www.ucvtscampuschronicle.com/single-post/2020/05/16/movie-review-frozen-2',
#  'https://www.ucvtscampuschronicle.com/single-post/opinion-the-decline-of-the-grammys',
#  'https://www.ucvtscampuschronicle.com/single-post/scandal-that-broke-the-national-women-s-soccer-league',
#  'https://www.ucvtscampuschronicle.com/single-post/everything-you-need-to-know-about-among-us',
#  'https://www.ucvtscampuschronicle.com/single-post/osu-a-game-with-its-own-rhythm',
#  'https://www.ucvtscampuschronicle.com/single-post/interesting-facts-about-the-human-memory',
#  'https://www.ucvtscampuschronicle.com/single-post/why-you-should-watch-the-marvel-movies',
#  'https://www.ucvtscampuschronicle.com/single-post/eddie-van-halen-obituary',
#  'https://www.ucvtscampuschronicle.com/single-post/the-staggering-decline-in-marvel-s-cinematic-universe',
#  'https://www.ucvtscampuschronicle.com/single-post/2020/05/17/english-a-frankenstein-monster-of-a-language-1',
#  'https://www.ucvtscampuschronicle.com/single-post/2020/05/16/a-controversial-fight-between-two-controversial-youtubers-logan-paul-vs-ksi-ii',
#  'https://www.ucvtscampuschronicle.com/single-post/what-lead-to-the-supreme-court-s-politicization']

# %%
authors = {
    'akash' : [
        "Akash Dubey",
        "AIT"
    ]
}

# %%
def get_author(short_name, full_name, school):
      author = f"""    {short_name}:
      name:           {full_name}
      site:           https://www.wowthemes.net
      avatar:         /assets/images/anonymous.jpg      role:           Member
      bio:            "Hi, I am {full_name}!"
      email:          no_reply@ucvts.org
      twitter:        https://twitter.com/
      school:         {school}
      grade:          Alumni"""
      return author

# %%
from datetime import datetime
import os
from dateutil import parser

def parse_datetime(date_string):
    try:
        parsed_date = parser.parse(date_string)
        return parsed_date.strftime("%Y-%m-%d")
    except ValueError as e:
        print(f"Failed to parse datetime: {str(e)}")
        try:
            return datetime.strptime(date, "%B %d, %Y").strftime("%Y-%m-%d")
        except ValueError:
            return datetime.strptime(date, "%b %d, %Y").strftime("%Y-%m-%d")
        return None

def save_image(url, name):
    # Send a request to the image URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Extract the file name from the URL
        filename = name + '.' +  os.path.basename(url).split('.')[-1]

        # Specify the file path where the image will be saved
        filepath = os.path.join("assets/images", filename)

        print(f"Downloading file from {url}")
        print(f"Saving the file as {filename}")

        # Save the image to the specified file path
        with open(filepath, "wb") as file:
            file.write(response.content)
        print("Image downloaded and saved successfully.")
        return filepath
    
    print("Failed to download the image. Status code:", response.status_code)
    return None

def save_file(url):
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
    else:
        print(f"Failed to fetch URL: {url}")
        return None

    article = soup.find(id='content-wrapper')
    image_url = article.find_all('img')[0].get('data-pin-media')
    title = article.find('h1').text
    print(title)
    text_list = [a.text for a in article.find_all('p')]

    text = '\n\n'.join(text_list)
    meta_data = [a.text for a in article.find_all('li')]
    try:
        full_name = meta_data[0].split(',')[0]
        school = meta_data[0].split(',')[1]
    except IndexError:
        print(meta_data)
        full_name = input("Enter full name: ")
        school = input("Enter School: ")
    
    short_name = full_name.split(' ')[0].lower()
    date = meta_data[3]
    category = meta_data[-1]

    # Convert title to valid filename
    short_title = title.lower().replace(" ", "-")

    good_file = "".join([char for char in short_title if char.isalnum() or char == '-'])

    path = save_image(image_url, good_file)

    article = f"""---
layout: post
title:  "{title}"
author: {short_name}
categories: [ {category} ]
image: {path}
---

{text}

"""

    authors[short_name] = [full_name, school, get_author(short_name, full_name, school)]

    # Parse the original date
    formatted_date = parse_datetime(date)


    # Create the file name by using the formatted date and title
    file_name = f"{formatted_date}-{good_file}.md"
    print(article, file=open(f"_posts/{file_name}", "w", encoding="ascii", errors="ignore"))
    return True

# %%
for result in reversed(campus_urls):
    try:
        save_file(result)
    except:
        print("Error with: " + result)
        continue
authors
# Out:
# Error with: https://www.ucvtscampuschronicle.com/single-post/what-lead-to-the-supreme-court-s-politicization
# A Controversial Fight Between Two Controversial Youtubers: Logan Paul vs KSI II
# Downloading file from https://static.wixstatic.com/media/057f98_5f16dacf376347aea90f64f80f1d1137~mv2.jpg/v1/fill/w_960,h_689,al_c,q_85/057f98_5f16dacf376347aea90f64f80f1d1137~mv2.jpg
# Saving the file as a-controversial-fight-between-two-controversial-youtubers-logan-paul-vs-ksi-ii.jpg
# Image downloaded and saved successfully.
# English, A Frankenstein Monster of a Language
# Downloading file from https://static.wixstatic.com/media/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png/v1/fill/w_960,h_540,al_c,q_90/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png
# Saving the file as english-a-frankenstein-monster-of-a-language.png
# Image downloaded and saved successfully.
# The Staggering Decline in Marvel's Cinematic Universe
# Downloading file from https://static.wixstatic.com/media/c50196_be20f61b250141b5b9b401a53edf84c9~mv2.webp
# Saving the file as the-staggering-decline-in-marvels-cinematic-universe.webp
# Image downloaded and saved successfully.
# Eddie Van Halen Obituary
# Downloading file from https://static.wixstatic.com/media/c70799_30b43f50badb41c89d50b3373f9b904c~mv2.jpg/v1/fill/w_957,h_646,al_c,q_85/c70799_30b43f50badb41c89d50b3373f9b904c~mv2.jpg
# Saving the file as eddie-van-halen-obituary.jpg
# Image downloaded and saved successfully.
# Why You Should Watch the Marvel Movies
# Downloading file from https://static.wixstatic.com/media/8ff735_f47059e73d514b2c803e06ea10b9745f~mv2.jpg/v1/fill/w_1280,h_608,al_c,q_85/8ff735_f47059e73d514b2c803e06ea10b9745f~mv2.jpg
# Saving the file as why-you-should-watch-the-marvel-movies.jpg
# Image downloaded and saved successfully.
# Interesting Facts About the Human Memory
# Downloading file from https://static.wixstatic.com/media/8ff735_30d05f0281a44443850c402b996730c8~mv2.jpg/v1/fill/w_1180,h_842,al_c,q_85/8ff735_30d05f0281a44443850c402b996730c8~mv2.jpg
# Saving the file as interesting-facts-about-the-human-memory.jpg
# Image downloaded and saved successfully.
# Osu!: A Game With its own Rhythm
# ['Rebecca Lee ', '', 'Mar 13, 20223 min read', 'Mar 13, 2022', '', '3 min read', 'Arts and Entertainment']
# Downloading file from https://static.wixstatic.com/media/f6d26c_1b22bd7878be4c6baf4c712200b56c7d~mv2.png/v1/fill/w_725,h_419,al_c,lg_1,q_85/f6d26c_1b22bd7878be4c6baf4c712200b56c7d~mv2.png
# Saving the file as osu-a-game-with-its-own-rhythm.png
# Image downloaded and saved successfully.
# Everything You Need to Know About Among Us
# Downloading file from https://static.wixstatic.com/media/94f6cf_4359db5417874fd88cd1a7a9d4d395d7~mv2.jpg/v1/fill/w_739,h_424,al_c,lg_1,q_80/94f6cf_4359db5417874fd88cd1a7a9d4d395d7~mv2.jpg
# Saving the file as everything-you-need-to-know-about-among-us.jpg
# Image downloaded and saved successfully.
# Scandal that broke the national women's soccer league
# Downloading file from https://static.wixstatic.com/media/11062b_1861df7badfc4005b2069e52984aa8ca~mv2.jpg/v1/fill/w_5000,h_3333,al_c,q_90,usm_0.66_1.00_0.01/11062b_1861df7badfc4005b2069e52984aa8ca~mv2.jpg
# Saving the file as scandal-that-broke-the-national-womens-soccer-league.jpg
# Image downloaded and saved successfully.
# Opinion: The Decline of the Grammys
# Downloading file from https://static.wixstatic.com/media/8ff735_f76fcee1df5a46ca99de9265ceaf2052~mv2.jpg/v1/fill/w_1642,h_924,al_c,q_85/8ff735_f76fcee1df5a46ca99de9265ceaf2052~mv2.jpg
# Saving the file as opinion-the-decline-of-the-grammys.jpg
# Image downloaded and saved successfully.
# Movie Review: Frozen 2
# Downloading file from https://static.wixstatic.com/media/057f98_6e8c182e0c324d968bb3679b145049f3~mv2.jpg/v1/fill/w_1024,h_487,al_c,q_85/057f98_6e8c182e0c324d968bb3679b145049f3~mv2.jpg
# Saving the file as movie-review-frozen-2.jpg
# Image downloaded and saved successfully.
# Lionel Messi & Cristiano Ronaldo: Football's Greatest Ever Players
# Downloading file from https://static.wixstatic.com/media/7e8fb8_a75e11ae4cab454b98a1ff49e68b0f4f~mv2.png/v1/fill/w_700,h_525,al_c,q_90/7e8fb8_a75e11ae4cab454b98a1ff49e68b0f4f~mv2.png
# Saving the file as lionel-messi--cristiano-ronaldo-footballs-greatest-ever-players.png
# Image downloaded and saved successfully.
# Modern Rejection of the Gender Binary
# Downloading file from https://static.wixstatic.com/media/c70799_4b2bf4746b8a4706bb8d36c54cc8a665~mv2.png/v1/fill/w_936,h_722,al_c,q_90/c70799_4b2bf4746b8a4706bb8d36c54cc8a665~mv2.png
# Saving the file as modern-rejection-of-the-gender-binary.png
# Image downloaded and saved successfully.
# Grey's Anatomy: How is It Still Running?
# Downloading file from https://static.wixstatic.com/media/8ff735_742aa04042a74e848f4c1ad14a3dfa6e~mv2.jpg/v1/fill/w_1600,h_900,al_c,q_85/8ff735_742aa04042a74e848f4c1ad14a3dfa6e~mv2.jpg
# Saving the file as greys-anatomy-how-is-it-still-running.jpg
# Image downloaded and saved successfully.
# Album Review: Nectar by Joji
# Downloading file from https://static.wixstatic.com/media/8ff735_468e83b634924ff5b4843abe4d8c13a6~mv2.png/v1/fill/w_3840,h_2160,al_c,q_95/8ff735_468e83b634924ff5b4843abe4d8c13a6~mv2.png
# Saving the file as album-review-nectar-by-joji.png
# Image downloaded and saved successfully.
# Hybrid vs. In-person Learning at UCVTS
# Downloading file from https://static.wixstatic.com/media/0089f9_051a5a1178194b35a39ced54a3da4dcf~mv2.jpg/v1/fill/w_1600,h_900,al_c,q_85/0089f9_051a5a1178194b35a39ced54a3da4dcf~mv2.jpg
# Saving the file as hybrid-vs-in-person-learning-at-ucvts.jpg
# Image downloaded and saved successfully.
# The Nobel Prize: A High Honor
# Downloading file from https://static.wixstatic.com/media/f98363_5187bdcabaef46e4812d2fe1b2ebb060~mv2.jpg/v1/fill/w_1600,h_900,al_c,q_85/f98363_5187bdcabaef46e4812d2fe1b2ebb060~mv2.jpg
# Saving the file as the-nobel-prize-a-high-honor.jpg
# Image downloaded and saved successfully.
# Harry Styles: Redefining Masculinity
# Downloading file from https://static.wixstatic.com/media/f14704_70b1db1ec9c94027a5c0f0462466f96b~mv2.png/v1/fill/w_576,h_575,al_c,lg_1,q_85/f14704_70b1db1ec9c94027a5c0f0462466f96b~mv2.png
# Saving the file as harry-styles-redefining-masculinity.png
# Image downloaded and saved successfully.
# How the Theft of the ‘Mona Lisa’ Launched an Ordinary Painting to Superstar Status
# Downloading file from https://static.wixstatic.com/media/nsplsh_71387354777474714b4659~mv2_d_3329_4993_s_4_2.jpg/v1/fill/w_3329,h_4993,al_c,q_90/nsplsh_71387354777474714b4659~mv2_d_3329_4993_s_4_2.jpg
# Saving the file as how-the-theft-of-the-mona-lisa-launched-an-ordinary-painting-to-superstar-status.jpg
# Image downloaded and saved successfully.
# Exercise During the Quarantine: Its Importance and How to Implement It in Your Own Life
# Downloading file from https://static.wixstatic.com/media/nsplsh_e2db0efee5c5492d96446bb1aabb09fb~mv2.jpg/v1/fill/w_5000,h_3571,al_c,q_90,usm_0.66_1.00_0.01/nsplsh_e2db0efee5c5492d96446bb1aabb09fb~mv2.jpg
# Saving the file as exercise-during-the-quarantine-its-importance-and-how-to-implement-it-in-your-own-life.jpg
# Image downloaded and saved successfully.
# Revolutionary Progress In Curing Alzheimer’s Disease
# Downloading file from https://static.wixstatic.com/media/0089f9_4f814e7338cf4bf287d00a7af90e13be~mv2.jpg/v1/fill/w_1200,h_800,al_c,q_85/0089f9_4f814e7338cf4bf287d00a7af90e13be~mv2.jpg
# Saving the file as revolutionary-progress-in-curing-alzheimers-disease.jpg
# Image downloaded and saved successfully.
# Death By Potatoes: Could Mark Watney Really Have Survived in “The Martian” ?
# Downloading file from https://static.wixstatic.com/media/0089f9_7fa1f34960a84680b0e539edd44f2cd5~mv2.jpg/v1/fill/w_960,h_540,al_c,q_85/0089f9_7fa1f34960a84680b0e539edd44f2cd5~mv2.jpg
# Saving the file as death-by-potatoes-could-mark-watney-really-have-survived-in-the-martian-.jpg
# Image downloaded and saved successfully.
# Don’t Burn Out In High School!
# Downloading file from https://static.wixstatic.com/media/c70799_06a91bf2fa164523a8e3f67f97d6d575~mv2.jpg/v1/fill/w_2000,h_1971,al_c,q_90/c70799_06a91bf2fa164523a8e3f67f97d6d575~mv2.jpg
# Saving the file as dont-burn-out-in-high-school.jpg
# Image downloaded and saved successfully.
# Covering the Transfer Window of the European Leagues (Soccer)
# Downloading file from https://static.wixstatic.com/media/8ff735_52488b9b3a284f02a3de52221ed50cca~mv2.jpeg/v1/fill/w_840,h_473,al_c,lg_1,q_85/8ff735_52488b9b3a284f02a3de52221ed50cca~mv2.jpeg
# Saving the file as covering-the-transfer-window-of-the-european-leagues-soccer.jpeg
# Image downloaded and saved successfully.
# La Esperantisto and the Beauty of Esperanto
# Downloading file from https://static.wixstatic.com/media/0089f9_783657c0e58b4df29d6677bf9af72628~mv2.jpg/v1/fill/w_528,h_683,al_c,lg_1,q_85/0089f9_783657c0e58b4df29d6677bf9af72628~mv2.jpg
# Saving the file as la-esperantisto-and-the-beauty-of-esperanto.jpg
# Image downloaded and saved successfully.
# Craziest Places on Earth That Look Fictional, But Aren’t!
# Downloading file from https://static.wixstatic.com/media/8ff735_2237864e380341fda94b51a897a270a2~mv2.png/v1/fill/w_717,h_403,al_c,lg_1,q_85/8ff735_2237864e380341fda94b51a897a270a2~mv2.png
# Saving the file as craziest-places-on-earth-that-look-fictional-but-arent.png
# Image downloaded and saved successfully.
# At the brink of an Artificial intelligence cold war
# Downloading file from https://static.wixstatic.com/media/c70799_66524295a4e847f1b048ef1e0af585cf~mv2.png/v1/fill/w_1200,h_675,al_c,q_90/c70799_66524295a4e847f1b048ef1e0af585cf~mv2.png
# Saving the file as at-the-brink-of-an-artificial-intelligence-cold-war.png
# Image downloaded and saved successfully.
# Greta Thunberg Leads Global Climate Strike
# Downloading file from https://static.wixstatic.com/media/0089f9_bd7bacb1c1b24a6ca56bba382502419d~mv2.jpg/v1/fill/w_992,h_558,al_c,q_85/0089f9_bd7bacb1c1b24a6ca56bba382502419d~mv2.jpg
# Saving the file as greta-thunberg-leads-global-climate-strike.jpg
# Image downloaded and saved successfully.
# Fast Fashion & Better Alternatives
# Downloading file from https://static.wixstatic.com/media/c70799_8bfebb95a2af4a6189887e9c3c2f727b~mv2.png/v1/fill/w_475,h_658,al_c,lg_1,q_85/c70799_8bfebb95a2af4a6189887e9c3c2f727b~mv2.png
# Saving the file as fast-fashion--better-alternatives-.png
# Image downloaded and saved successfully.
# Why you Should Watch She-Ra and the Princesses of Power
# Downloading file from https://static.wixstatic.com/media/0089f9_f67045e9200d4bdf92edacc7a87a326e~mv2.jpg/v1/fill/w_1100,h_619,al_c,q_85/0089f9_f67045e9200d4bdf92edacc7a87a326e~mv2.jpg
# Saving the file as why-you-should-watch-she-ra-and-the-princesses-of-power.jpg
# Image downloaded and saved successfully.
# Casper Ruud: Tennis’ Next Star
# Downloading file from https://static.wixstatic.com/media/4c5e49_815ce560fc484c93803a1756e7371e5d~mv2.png/v1/fill/w_736,h_412,al_c,lg_1,q_85/4c5e49_815ce560fc484c93803a1756e7371e5d~mv2.png
# Saving the file as casper-ruud-tennis-next-star.png
# Image downloaded and saved successfully.
# The Fast fashion industry: An ethical overview
# Downloading file from https://static.wixstatic.com/media/nsplsh_6f6a5a34774a4e554d3577~mv2_d_4971_3320_s_4_2.jpg/v1/fill/w_4971,h_3320,al_c,q_90/nsplsh_6f6a5a34774a4e554d3577~mv2_d_4971_3320_s_4_2.jpg
# Saving the file as the-fast-fashion-industry-an-ethical-overview.jpg
# Image downloaded and saved successfully.
# Recap of the 2022 MLB Season
# Downloading file from https://static.wixstatic.com/media/8ff735_8b973b540f554629910afec6a3ee6cc2~mv2.jpg/v1/fill/w_614,h_409,al_c,lg_1,q_80/8ff735_8b973b540f554629910afec6a3ee6cc2~mv2.jpg
# Saving the file as recap-of-the-2022-mlb-season.jpg
# Image downloaded and saved successfully.
# A Book Review sans Spoilers: Never Let Me Go by Kazuo Ishiguro
# Downloading file from https://static.wixstatic.com/media/0089f9_8358edb6e4f14cd582a963437d744472~mv2.jpg/v1/fill/w_563,h_900,al_c,q_85/0089f9_8358edb6e4f14cd582a963437d744472~mv2.jpg
# Saving the file as a-book-review-sans-spoilers-never-let-me-go-by-kazuo-ishiguro.jpg
# Image downloaded and saved successfully.
# Julian Assange's Extradition Ruling
# Downloading file from https://static.wixstatic.com/media/c70799_27bff4721d8b44ae899ddca3ef87fb33~mv2.png/v1/fill/w_840,h_473,al_c,lg_1,q_90/c70799_27bff4721d8b44ae899ddca3ef87fb33~mv2.png
# Saving the file as julian-assanges-extradition-ruling-.png
# Image downloaded and saved successfully.
# How Countries Have Handled Coronavirus
# Downloading file from https://static.wixstatic.com/media/f98363_c5c1ebd337cd413499cdf6e1f40f2312~mv2.jpg/v1/fill/w_936,h_526,al_c,lg_1,q_85/f98363_c5c1ebd337cd413499cdf6e1f40f2312~mv2.jpg
# Saving the file as how-countries-have-handled-coronavirus.jpg
# Image downloaded and saved successfully.
# Interview with Mrs. Mansfield-Smith, Principal of Magnet High School
# Downloading file from https://static.wixstatic.com/media/0089f9_a68f79db055845739aa20050b2699d7d~mv2.jpg/v1/fill/w_350,h_234,al_c,lg_1,q_80/0089f9_a68f79db055845739aa20050b2699d7d~mv2.jpg
# Saving the file as interview-with-mrs-mansfield-smith-principal-of-magnet-high-school.jpg
# Image downloaded and saved successfully.
# The Greatness of Breaking Bad
# Downloading file from https://static.wixstatic.com/media/7fd0df_386b319ae8cf47408a1e9b4ff04be03b~mv2.png/v1/fill/w_717,h_403,al_c,lg_1,q_85/7fd0df_386b319ae8cf47408a1e9b4ff04be03b~mv2.png
# Saving the file as the-greatness-of-breaking-bad.png
# Image downloaded and saved successfully.
# The Science Behind the Shot: How Vaccines Work
# Downloading file from https://static.wixstatic.com/media/0089f9_79ce15aca1974fa1bddc164b2445fa9c~mv2.png/v1/fill/w_800,h_318,al_c,lg_1,q_85/0089f9_79ce15aca1974fa1bddc164b2445fa9c~mv2.png
# Saving the file as the-science-behind-the-shot-how-vaccines-work.png
# Image downloaded and saved successfully.
# Outsourcing to China is Depleting the United States GDP
# Downloading file from https://static.wixstatic.com/media/0089f9_9794af1e83b14eb4a9e50ddeb9bd6400~mv2.jpg/v1/fill/w_890,h_501,al_c,q_85/0089f9_9794af1e83b14eb4a9e50ddeb9bd6400~mv2.jpg
# Saving the file as outsourcing-to-china-is-depleting-the-united-states-gdp.jpg
# Image downloaded and saved successfully.
# Young Voters and Midterm Elections: What’s the Connection?
# Downloading file from https://static.wixstatic.com/media/4c5e49_dc123f23fc2c4dac9e351de8ab10e2ad~mv2.png/v1/fill/w_804,h_446,al_c,lg_1,q_85/4c5e49_dc123f23fc2c4dac9e351de8ab10e2ad~mv2.png
# Saving the file as young-voters-and-midterm-elections-whats-the-connection-.png
# Image downloaded and saved successfully.
# Your Brain on the Holidays
# Downloading file from https://static.wixstatic.com/media/0089f9_447e0da5740b42d396c5db865124bfb2~mv2.jpg/v1/fill/w_740,h_565,al_c,q_85/0089f9_447e0da5740b42d396c5db865124bfb2~mv2.jpg
# Saving the file as your-brain-on-the-holidays.jpg
# Image downloaded and saved successfully.
# Humans on Mars | SpaceX’s Quest to Colonize the Red Planet
# Downloading file from https://static.wixstatic.com/media/nsplsh_4e525f745854757954616b~mv2_d_4240_2384_s_2.jpg/v1/fill/w_4240,h_2384,al_c,q_90/nsplsh_4e525f745854757954616b~mv2_d_4240_2384_s_2.jpg
# Saving the file as humans-on-mars--spacexs-quest-to-colonize-the-red-planet.jpg
# Image downloaded and saved successfully.
# Concert Review: The Regrettes at Bowery Ballroom
# Downloading file from https://static.wixstatic.com/media/0089f9_fef08630ed2c452bba00d0f7aa3cb491~mv2.png/v1/fill/w_710,h_466,al_c,lg_1,q_85/0089f9_fef08630ed2c452bba00d0f7aa3cb491~mv2.png
# Saving the file as concert-review-the-regrettes-at-bowery-ballroom.png
# Image downloaded and saved successfully.
# Boutiques around union county: Millburn edition
# [' Sara Schwartz-AAHS', '', 'Jun 15, 20216 min read', 'Jun 15, 2021', '', '6 min read', 'Opinion', '•', 'Arts and Entertainment']
# Downloading file from https://static.wixstatic.com/media/c70799_f4737f169aef4670b93dabeaa28c614e~mv2.png/v1/fill/w_2200,h_1362,al_c,q_95/c70799_f4737f169aef4670b93dabeaa28c614e~mv2.png
# Saving the file as boutiques-around-union-county-millburn-edition.png
# Image downloaded and saved successfully.
# Open Veins of Latin America: Yea or Nay Book Review
# Downloading file from https://static.wixstatic.com/media/c70799_3863bc1756c84b338bd5eb541569cc72~mv2.png/v1/fill/w_2094,h_1144,al_c,q_95/c70799_3863bc1756c84b338bd5eb541569cc72~mv2.png
# Saving the file as open-veins-of-latin-america-yea-or-nay-book-review.png
# Image downloaded and saved successfully.
# Album review: After the Gold Rush by Neil young
# Downloading file from https://static.wixstatic.com/media/f98363_e23f63b1afb9445eaaf4fb7604f0b008~mv2.jpg/v1/fill/w_1500,h_1005,al_c,q_85/f98363_e23f63b1afb9445eaaf4fb7604f0b008~mv2.jpg
# Saving the file as album-review-after-the-gold-rush-by-neil-young.jpg
# Image downloaded and saved successfully.
# Climate Change: The Floods in Pakistan
# Downloading file from https://static.wixstatic.com/media/7cc035_9ce0b0fc9110405c9fbaeba07dd98ce6~mv2.png/v1/fill/w_427,h_242,al_c,lg_1,q_85/7cc035_9ce0b0fc9110405c9fbaeba07dd98ce6~mv2.png
# Saving the file as climate-change-the-floods-in-pakistan.png
# Image downloaded and saved successfully.
# The Lack of Innovation at Apple
# Downloading file from https://static.wixstatic.com/media/nsplsh_5b6e1a7f1a19440aaac1111a150ebeed~mv2.jpg/v1/fill/w_5000,h_3333,al_c,q_90,usm_0.66_1.00_0.01/nsplsh_5b6e1a7f1a19440aaac1111a150ebeed~mv2.jpg
# Saving the file as the-lack-of-innovation-at-apple.jpg
# Image downloaded and saved successfully.
# Track 5: Union County’s Favorite Cup ‘O Joe
# Downloading file from https://static.wixstatic.com/media/7f23f6_988f2dfddd96494e98d39c1761876fea~mv2.png/v1/fill/w_441,h_332,al_c,lg_1,q_85/7f23f6_988f2dfddd96494e98d39c1761876fea~mv2.png
# Saving the file as track-5-union-countys-favorite-cup-o-joe.png
# Image downloaded and saved successfully.
# Restaurant Reviews Around Union County
# Downloading file from https://static.wixstatic.com/media/0089f9_787e78a9bd7842ad80c590d762dcc30a~mv2.png/v1/fill/w_664,h_468,al_c,lg_1,q_85/0089f9_787e78a9bd7842ad80c590d762dcc30a~mv2.png
# Saving the file as restaurant-reviews-around-union-county.png
# Image downloaded and saved successfully.
# How a Person's Outlook on Death Affects Their Outlook on Life
# Downloading file from https://static.wixstatic.com/media/f98363_1cc2499e36864ab684fbdb8f78d5f3d0~mv2.jpg/v1/fill/w_808,h_552,al_c,q_85/f98363_1cc2499e36864ab684fbdb8f78d5f3d0~mv2.jpg
# Saving the file as how-a-persons-outlook-on-death-affects-their-outlook-on-life.jpg
# Image downloaded and saved successfully.
# Behind the Curtain: A Sneak Peak at the Process of Bringing a Play to Life
# ['Lilly Resnick ', '', 'Mar 18, 20221 min read', 'Mar 18, 2022', '', '1 min read', 'Arts and Entertainment']
# Downloading file from https://static.wixstatic.com/media/nsplsh_6dd813d2ab2d4185aaa208ed904e3ab7~mv2.jpg/v1/fill/w_3750,h_2500,al_c,q_90/nsplsh_6dd813d2ab2d4185aaa208ed904e3ab7~mv2.jpg
# Saving the file as behind-the-curtain-a-sneak-peak-at-the-process-of-bringing-a-play-to-life.jpg
# Image downloaded and saved successfully.
# Why Rising Gas Prices are Important
# Downloading file from https://static.wixstatic.com/media/f827837d7af34a9399423642bfc8c7a9.jpg/v1/fill/w_3872,h_2592,al_c,q_90/f827837d7af34a9399423642bfc8c7a9.jpg
# Saving the file as why-rising-gas-prices-are-important.jpg
# Image downloaded and saved successfully.
# Error with: https://www.ucvtscampuschronicle.com/single-post/stage-fright-a-monologue
# 5 Fruits That Are Good For You!
# Downloading file from https://static.wixstatic.com/media/4d881061e1454749bc6182cb6d64dcaf.jpg/v1/fill/w_5000,h_3333,al_c,q_90,usm_0.66_1.00_0.01/4d881061e1454749bc6182cb6d64dcaf.jpg
# Saving the file as 5-fruits-that-are-good-for-you.jpg
# Image downloaded and saved successfully.
# Open Letter Submission
# ['Anonymous', '', 'Feb 17, 20213 min read', 'Feb 17, 2021', '', '3 min read', 'Opinion']
# Downloading file from https://static.wixstatic.com/media/0089f9_08b5f893dd114ef2ab350a984b7f967b~mv2.jpeg/v1/fill/w_1000,h_666,al_c,q_85/0089f9_08b5f893dd114ef2ab350a984b7f967b~mv2.jpeg
# Saving the file as open-letter-submission.jpeg
# Image downloaded and saved successfully.
# Misogyny in Everyday Life
# Downloading file from https://static.wixstatic.com/media/599d5afdcec7458e9a131b2189cfd232.jpg/v1/fill/w_5000,h_3333,al_c,q_90,usm_0.66_1.00_0.01/599d5afdcec7458e9a131b2189cfd232.jpg
# Saving the file as misogyny-in-everyday-life.jpg
# Image downloaded and saved successfully.
# The Problem with Spotify Wrapped
# Downloading file from https://static.wixstatic.com/media/4c5e49_ef1762ce1a1b46929e0042c59e801995~mv2.png/v1/fill/w_894,h_499,al_c,lg_1,q_90/4c5e49_ef1762ce1a1b46929e0042c59e801995~mv2.png
# Saving the file as the-problem-with-spotify-wrapped.png
# Image downloaded and saved successfully.
# The Fashion Industry’s Not-So-Secret Impact
# Downloading file from https://static.wixstatic.com/media/7cc035_0c8a029063b847a4b958d539e4c04518~mv2.png/v1/fill/w_745,h_312,al_c,lg_1,q_85/7cc035_0c8a029063b847a4b958d539e4c04518~mv2.png
# Saving the file as the-fashion-industrys-not-so-secret-impact.png
# Image downloaded and saved successfully.
# How Shows and Movies are Filming During the Pandemic
# Failed to download the image. Status code: 403
# How TikTok is Quickening the Fashion Trend Cycle
# Downloading file from https://static.wixstatic.com/media/4c5e49_75fc1ca608864ea3a408075fb5b1a3c5~mv2.png/v1/fill/w_728,h_666,al_c,lg_1,q_90/4c5e49_75fc1ca608864ea3a408075fb5b1a3c5~mv2.png
# Saving the file as how-tiktok-is-quickening-the-fashion-trend-cycle.png
# Image downloaded and saved successfully.
# ChatGPT's Meteoric Rise: What Does the Future of Communication Look Like?
# Downloading file from https://static.wixstatic.com/media/8ff735_6e65d4fae3b248d9a5fca02bc64bbeb4~mv2.png/v1/fill/w_614,h_409,al_c,lg_1,q_85/8ff735_6e65d4fae3b248d9a5fca02bc64bbeb4~mv2.png
# Saving the file as chatgpts-meteoric-rise-what-does-the-future-of-communication-look-like.png
# Image downloaded and saved successfully.
# Practicing self-love
# Downloading file from https://static.wixstatic.com/media/nsplsh_c62c6a9126fa47c3a2ab177c471541e3~mv2.jpg/v1/fill/w_3707,h_2080,al_c,q_90/nsplsh_c62c6a9126fa47c3a2ab177c471541e3~mv2.jpg
# Saving the file as practicing-self-love.jpg
# Image downloaded and saved successfully.
# {'akash': ['Akash Dubey', 'AIT'],
#  'alan': ['Alan Ostrovsky',
#   ' AIT',
#   '    alan:\n      name:           Alan Ostrovsky\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Alan Ostrovsky!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'joe': ['Joe Baldwin',
#   ' UCTech',
#   '    joe:\n      name:           Joe Baldwin\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Joe Baldwin!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'omolola': ['Omolola Falana',
#   ' MHS',
#   '    omolola:\n      name:           Omolola Falana\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Omolola Falana!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'haralambos': ['Haralambos Liberatos',
#   ' UCTech',
#   '    haralambos:\n      name:           Haralambos Liberatos\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Haralambos Liberatos!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'victoria': ['Victoria Gee',
#   ' MHS',
#   '    victoria:\n      name:           Victoria Gee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Victoria Gee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'laura': ['Laura Felder',
#   ' UCTech',
#   '    laura:\n      name:           Laura Felder\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Laura Felder!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'rebecca': ['Rebecca Lee',
#   'AIT',
#   '    rebecca:\n      name:           Rebecca Lee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Rebecca Lee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         AIT\n      grade:          Alumni'],
#  '': [' Sara Schwartz',
#   ' AAHS',
#   '    :\n      name:            Sara Schwartz\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am  Sara Schwartz!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'audrey': ['Audrey Miller',
#   ' UCTech',
#   '    audrey:\n      name:           Audrey Miller\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Audrey Miller!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'natalie': ['Natalie Lee',
#   ' MHS',
#   '    natalie:\n      name:           Natalie Lee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Natalie Lee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'dylan': ['Dylan Intwala',
#   ' AIT',
#   '    dylan:\n      name:           Dylan Intwala\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Dylan Intwala!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'alondra': ['Alondra Martinez',
#   ' UCTech',
#   '    alondra:\n      name:           Alondra Martinez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Alondra Martinez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'ernest': ['Ernest Romero',
#   ' APA',
#   '    ernest:\n      name:           Ernest Romero\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Ernest Romero!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
#  'gregory': ['Gregory Martinez',
#   ' AAHS',
#   '    gregory:\n      name:           Gregory Martinez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Gregory Martinez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'maya': ['Maya Dias',
#   ' AIT',
#   '    maya:\n      name:           Maya Dias\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Maya Dias!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'shreya': ['Shreya Nara',
#   ' AIT',
#   '    shreya:\n      name:           Shreya Nara\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Shreya Nara!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'ella': ['Ella Platts',
#   ' UCTech',
#   '    ella:\n      name:           Ella Platts\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Ella Platts!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'monica': ['Monica Manescu',
#   ' AAHS',
#   '    monica:\n      name:           Monica Manescu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Monica Manescu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'diya': ['Diya Nainwal',
#   ' AAHS',
#   '    diya:\n      name:           Diya Nainwal\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Diya Nainwal!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'kenna': ['Kenna Srivastava',
#   ' MHS',
#   '    kenna:\n      name:           Kenna Srivastava\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Kenna Srivastava!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'saniya': ['Saniya Harlalka',
#   ' AAHS',
#   '    saniya:\n      name:           Saniya Harlalka\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Saniya Harlalka!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'justin': ['Justin Zimmerman',
#   ' AIT',
#   '    justin:\n      name:           Justin Zimmerman\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Justin Zimmerman!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'sarah': ['Sarah Bauman',
#   ' APA',
#   '    sarah:\n      name:           Sarah Bauman\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Sarah Bauman!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
#  'kaitlyn': ['Kaitlyn Landaverde',
#   ' APA',
#   '    kaitlyn:\n      name:           Kaitlyn Landaverde\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Kaitlyn Landaverde!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
#  'mattia': ['Mattia Leingang',
#   ' AIT',
#   '    mattia:\n      name:           Mattia Leingang\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Mattia Leingang!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'eric': ['Eric Yu',
#   ' AIT',
#   '    eric:\n      name:           Eric Yu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Eric Yu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'megan': ['Megan Lahetta',
#   ' UCTech',
#   '    megan:\n      name:           Megan Lahetta\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Megan Lahetta!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'daivya': ['Daivya Sadhvani',
#   ' AIT',
#   '    daivya:\n      name:           Daivya Sadhvani\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Daivya Sadhvani!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'jaime': ['Jaime Paladi',
#   ' AIT',
#   '    jaime:\n      name:           Jaime Paladi\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Jaime Paladi!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'akwele': ['Akwele Lokko',
#   ' AAHS',
#   '    akwele:\n      name:           Akwele Lokko\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Akwele Lokko!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'patrick': ['Patrick Mochnal',
#   ' AIT',
#   '    patrick:\n      name:           Patrick Mochnal\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Patrick Mochnal!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'haley': ['Haley Richardson',
#   ' UCTech',
#   '    haley:\n      name:           Haley Richardson\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Haley Richardson!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
#  'anusha': ['Anusha Iyer',
#   ' AIT',
#   '    anusha:\n      name:           Anusha Iyer\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Anusha Iyer!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'chloe': ['Chloe Gavula',
#   ' APA',
#   '    chloe:\n      name:           Chloe Gavula\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Chloe Gavula!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
#  'sara': ['Sara Schwartz',
#   ' AAHS',
#   '    sara:\n      name:           Sara Schwartz\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Sara Schwartz!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'ahmad': ['Ahmad Khizar',
#   ' AAHS',
#   '    ahmad:\n      name:           Ahmad Khizar\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Ahmad Khizar!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
#  'ana': ['Ana Obradovic',
#   ' AIT',
#   '    ana:\n      name:           Ana Obradovic\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Ana Obradovic!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'rachel': ['Rachel Bataille',
#   ' MHS',
#   '    rachel:\n      name:           Rachel Bataille\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Rachel Bataille!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'lilly': ['Lilly Resnick',
#   'AIT',
#   '    lilly:\n      name:           Lilly Resnick\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Lilly Resnick!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         AIT\n      grade:          Alumni'],
#  'ivy': ['Ivy Liu',
#   ' MHS',
#   '    ivy:\n      name:           Ivy Liu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Ivy Liu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
#  'anonymous': ['Anonymous',
#   'Unknown',
#   '    anonymous:\n      name:           Anonymous\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Anonymous!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         Unknown\n      grade:          Alumni'],
#  'sophia': ['Sophia Mekbeb',
#   ' APA',
#   '    sophia:\n      name:           Sophia Mekbeb\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Sophia Mekbeb!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
#  'mila': ['Mila Talati',
#   ' AIT',
#   '    mila:\n      name:           Mila Talati\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Mila Talati!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
#  'gissele': ['Gissele Hernandez',
#   ' UCTech',
#   '    gissele:\n      name:           Gissele Hernandez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
#       role:           Member\n      bio:            "Hi, I am Gissele Hernandez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni']}

# %%
url = "https://www.ucvtscampuschronicle.com/single-post/2020/05/17/english-a-frankenstein-monster-of-a-language-1"
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
else:
    print(f"Failed")

# %%
save_file("https://www.ucvtscampuschronicle.com/single-post/2020/05/17/english-a-frankenstein-monster-of-a-language-1")
# Out:
# Downloading file from https://static.wixstatic.com/media/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png/v1/fill/w_960,h_540,al_c,q_90/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png
# Saving the file as english,-a-frankenstein-monster-of-a-language.png
# Image downloaded and saved successfully.
# True

# %%
article = soup.find(id='content-wrapper')
article
# Out:
# <div id="content-wrapper"><div class="mbKyhH fsZ7OF mFmpGg blog-post-page-font" data-hook="post-page"><div class="KYa5Ob"><div></div><div><div><div><div class="EcwjNF"><article class="j3D9DG blog-post-page-font blog-card-background-color blog-card-border-color blog-text-color" data-hook="post" style="border-width:0"><div class="OSxNQL"><div class="OFA52E"><div class="IeNfNP"><ul class="xUuoH9 v0bFi9"><li class="F4tRtJ"><span class="" style="pointer-events:none"><div class="lBv2XN blog-text-color blog-link-hover-color avatar blog-post-text-color"><span class="tQ0Q1A user-name dlINDG" data-hook="user-name" title="Joe Baldwin, UCTech">Joe Baldwin, UCTech</span></div></span></li><li class="F4tRtJ"><div class="Ki_0_s rmqd9q blog-separator-background-color"></div></li><li class="F4tRtJ"><ul class="xUuoH9 MBUSKJ"><li class="UZa2Xr"><span class="post-metadata__date time-ago" data-hook="time-ago" title="May 17, 2020">May 17, 2020</span></li><li class="UZa2Xr"><div class="Ki_0_s rmqd9q blog-separator-background-color"></div></li><li class="UZa2Xr"><span class="post-metadata__readTime" data-hook="time-to-read" title="4 min read">4 min read</span></li></ul></li></ul><div class="UPa2xo JDQ812"><button aria-label="More actions" aria-pressed="false" class="u5Zxn8 jG7PL8 _EA3Ke more-button" data-hook="more-button" id="more-button-7c01d4d9-40b7-4950-97fa-9a733f34d041" type="button"><span class="Bvf4SR"><svg class="blog-icon-fill blog-post-homepage-link-hashtag-hover-fill" role="img" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg"><path d="M2.44398805,5.99973295 C1.62345525,5.9690612 0.980075653,5.28418875 1.00047182,4.46312144 C1.02086799,3.64205413 1.69745853,2.98998831 2.51850166,3.0001164 C3.33954478,3.01024449 3.99985313,3.67880182 4,4.50012255 C3.98424812,5.34399206 3.28763905,6.0153508 2.44398805,5.99973295 L2.44398805,5.99973295 Z M2.44398805,10.9997329 C1.62345525,10.9690612 0.980075653,10.2841888 1.00047182,9.46312144 C1.02086799,8.64205413 1.69745853,7.98998831 2.51850166,8.0001164 C3.33954478,8.01024449 3.99985313,8.67880182 4,9.50012255 C3.98424812,10.3439921 3.28763905,11.0153508 2.44398805,10.9997329 L2.44398805,10.9997329 Z M2.44398805,15.9997329 C1.62345525,15.9690612 0.980075653,15.2841888 1.00047182,14.4631214 C1.02086799,13.6420541 1.69745853,12.9899883 2.51850166,13.0001164 C3.33954478,13.0102445 3.99985313,13.6788018 4,14.5001225 C3.98424812,15.3439921 3.28763905,16.0153508 2.44398805,15.9997329 L2.44398805,15.9997329 Z"></path></svg></span></button></div></div><div class="cD_92h UitnHM" data-hook="post-title" tabindex="-1"><h1 class="UbhFJ7 nkqC0Q blog-post-title-font blog-post-title-color blog-text-color post-title blog-hover-container-element-color FG3qXk blog-post-page-title-font" data-hook="post-title"><span class="post-title__text blog-post-title-font blog-post-title-color"><span class="blog-post-title-font blog-post-title-color">English, A Frankenstein Monster of a Language</span></span></h1></div></div><div class="nLG8d5" data-hook="post-description"><article class="blog-post-page-font"><div class="post-content__body"><div class="moHCnT"><div class="moHCnT"><div class="fTEXDR A2sIZ4 QEEfz0" data-rce-version="9.14.3" style="--rce-text-color:rgb(0, 0, 0);--rce-opaque-background-color:rgb(182, 197, 209);--rce-divider-color:rgba(0, 0, 0, 0.2);--rce-active-divider-color:rgba(0, 0, 0, 0.5);--rce-highlighted-color:rgb(62, 204, 181);--rce-link-hashtag-color:rgb(0, 93, 170);--rce-mobile-font-size:16px;--rce-header-two-font-size:25px;--rce-header-three-font-size:19px;--rce-header-four-font-size:17px;--rce-header-five-font-size:15px;--rce-header-six-font-size:13px;--rce-mobile-header-two-font-size:24px;--rce-mobile-header-three-font-size:20px;--rce-mobile-header-four-font-size:20px;--rce-mobile-header-five-font-size:20px;--rce-mobile-header-six-font-size:20px;--rce-mobile-quotes-font-size:20px"><style type="text/css">
#   .post-content__body {
#     --ricos-text-color: #000000;
#     --ricos-text-color-tuple: 0, 0, 0;
#     --ricos-action-color: #3eccb5;
#     --ricos-action-color-tuple: 62, 204, 181;
#     --ricos-background-color: #b6c5d1;
#     --ricos-background-color-tuple: 182, 197, 209;
#     --ricos-fallback-color: #000000;
#     --ricos-fallback-color-tuple: 0, 0, 0;
#     --ricos-action-color-fallback: #000000;
#     --ricos-action-color-fallback-tuple: 0, 0, 0;
#         --ricos-custom-h1-font-weight: bold;
#     --ricos-custom-h1-font-size: 28px;
#     --ricos-custom-h1-line-height: 1.5;
#     --ricos-custom-h1-font-family: lulo-clean-w01-one-bold,lulo-clean-w05-one-bold,sans-serif;
#     --ricos-custom-h1-color: rgba(0,0,0,1);
#     --ricos-custom-h2-font-weight: bold;
#     --ricos-custom-h2-font-size: 25px;
#     --ricos-custom-h2-line-height: 1.5;
#     --ricos-custom-h2-font-family: lulo-clean-w01-one-bold,lulo-clean-w05-one-bold,sans-serif;
#     --ricos-custom-h2-color: rgba(0,0,0,1);
#     --ricos-custom-h3-font-weight: bold;
#     --ricos-custom-h3-font-size: 19px;
#     --ricos-custom-h3-line-height: 1.5;
#     --ricos-custom-h3-font-family: lulo-clean-w01-one-bold,lulo-clean-w05-one-bold,sans-serif;
#     --ricos-custom-h3-color: rgba(0,0,0,1);
#     --ricos-custom-h4-font-size: 44px;
#     --ricos-custom-h4-line-height: 1.5;
#     --ricos-custom-h4-font-family: playfair display,serif;
#     --ricos-custom-h4-color: #212121;
#     --ricos-custom-h5-font-weight: bold;
#     --ricos-custom-h5-font-size: 36px;
#     --ricos-custom-h5-line-height: 1.5;
#     --ricos-custom-h5-font-family: playfair display,serif;
#     --ricos-custom-h5-color: #212121;
#     --ricos-custom-h6-font-size: 19px;
#     --ricos-custom-h6-line-height: 1.5;
#     --ricos-custom-h6-font-family: avenir-lt-w01_35-light1475496,avenir-lt-w05_35-light,sans-serif;
#     --ricos-custom-h6-color: #212121;
#     --ricos-custom-link-line-height: 1.5;
#     --ricos-custom-link-text-decoration: inherit;
#     --ricos-custom-link-color: rgba(0,93,170,1);
#     --ricos-custom-link-font-style: inherit;
#     --ricos-custom-link-font-weight: inherit;
#     --ricos-custom-hashtag-line-height: 1.5;
#     --ricos-custom-hashtag-text-decoration: inherit;
#     --ricos-custom-hashtag-color: rgba(0,93,170,1);
#     --ricos-custom-hashtag-font-style: inherit;
#     --ricos-custom-hashtag-font-weight: inherit;
#     --ricos-custom-quote-font-size: 24px;
#     --ricos-custom-quote-line-height: 1.5;
#     --ricos-custom-quote-font-family: play,sans-serif;
#     --ricos-custom-quote-color: rgba(0,0,0,1);
#     --ricos-custom-quote-border-color: rgb(0, 93, 170);
#     --ricos-custom-p-font-size: 15px;
#     --ricos-custom-p-line-height: 1.5;
#     --ricos-custom-p-font-family: tahoma,tahoma-w01-regular,tahoma-w02-regular,tahoma-w10-regular,tahoma-w15--regular,tahoma-w99-regular,sans-serif;
#     --ricos-custom-p-text-decoration: inherit;
#     --ricos-custom-p-color: rgba(0,0,0,1);
#     --ricos-custom-p-font-style: inherit;
#     --ricos-custom-p-font-weight: inherit;
#   }
# </style><div class="itVXy dojW8l s6hjqn _8a1b4" data-id="rich-content-viewer" dir="ltr"><div class="mhGZq BAGeNT"><div data-hook="rcv-block-first" type="first"></div><div class="xVISr Y9Dpf bCMSCT OZy-3 lnyWN yMZv8w bCMSCT public-DraftStyleDefault-block-depth0 fixed-tab-size public-DraftStyleDefault-text-ltr" id="viewer-zxabh"><span class="B2EFF public-DraftStyleDefault-ltr"><span><br role="presentation"/></span></span></div><div data-hook="rcv-block1" type="empty-line"></div><div class="QHjDE rzoRKE" id="viewer-z7z95"><div class="gO6aa y8JqQg y8JqQg UAgbc OXFdk4 OXFdk4"><div class="Q6a5A" data-hook="imageViewer" role="button" tabindex="0"><div aria-label="" class="vBPBf L9OMM XHhj0" id="new-image25332697" style="--dim-height:540;--dim-width:960"><wow-image class="gXpdtc" data-animate-blur="" data-bg-effect-name="" data-has-ssr-src="true" data-image-info='{"containerId":"new-image25332697","displayMode":"fill","isLQIP":true,"isSEOBot":false,"lqipTransition":"blur","imageData":{"width":960,"height":540,"uri":"0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png","name":"","displayMode":"fill"}}' id="0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png"><img alt="" data-pin-media="https://static.wixstatic.com/media/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png/v1/fill/w_960,h_540,al_c,q_90/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png" data-pin-url="https://www.ucvtscampuschronicle.com/single-post/2020/05/17/english-a-frankenstein-monster-of-a-language-1" src="https://static.wixstatic.com/media/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png/v1/fill/w_48,h_27,al_c,q_85,usm_0.66_1.00_0.01,blur_2,enc_auto/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png" style="width:100%;height:100%;object-fit:cover;object-position:50% 50%;max-width:100%"/></wow-image><div class="PiI7v"><svg class="Nh3F1" viewbox="0 0 19 19" xmlns="http://www.w3.org/2000/svg"><path d="M15.071 8.371V4.585l-4.355 4.356a.2.2 0 0 1-.283 0l-.374-.374a.2.2 0 0 1 0-.283l4.356-4.355h-3.786a.2.2 0 0 1-.2-.2V3.2c0-.11.09-.2.2-.2H16v5.371a.2.2 0 0 1-.2.2h-.529a.2.2 0 0 1-.2-.2zm-6.5 6.9v.529a.2.2 0 0 1-.2.2H3v-5.371c0-.11.09-.2.2-.2h.529c.11 0 .2.09.2.2v3.786l4.355-4.356a.2.2 0 0 1 .283 0l.374.374a.2.2 0 0 1 0 .283L4.585 15.07h3.786c.11 0 .2.09.2.2z" fill="#000" fill-rule="nonzero"></path></svg></div></div><div class=""></div><div class=""></div></div></div></div><div data-hook="rcv-block2" type="image"></div><p class="xVISr Y9Dpf bCMSCT OZy-3 lnyWN yMZv8w bCMSCT public-DraftStyleDefault-block-depth0 fixed-tab-size public-DraftStyleDefault-text-ltr" id="viewer-ol6oa"><span class="B2EFF public-DraftStyleDefault-ltr"><span> </span></span></p><div data-hook="rcv-block3" type="paragraph"></div><p class="xVISr Y9Dpf bCMSCT OZy-3 lnyWN yMZv8w bCMSCT public-DraftStyleDefault-block-depth0 fixed-tab-size public-DraftStyleDefault-text-ltr" id="viewer-5ruyr"><span class="B2EFF public-DraftStyleDefault-ltr"><span>English is a weird language. Any student who has had to memorize strange spelling anomalies or had to read aloud in class only to trip over a word with two different meanings and entirely different pronunciations can attest to this. For example, though they masquerade as the same word, lead (as in leader) and lead (as in the element) sound different when spoken. Taken to the extreme, sentences like “Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo” make complete grammatical sense. And, perhaps, consider that English is one of the only European languages in which nouns are not assigned gender. </span></span></p><div data-hook="rcv-block4" type="paragraph"></div><p class="xVISr Y9Dpf bCMSCT OZy-3 lnyWN yMZv8w bCMSCT public-DraftStyleDefault-block-depth0 fixed-tab-size public-DraftStyleDefault-text-ltr" id="viewer-5l344"><span class="B2EFF public-DraftStyleDefault-ltr"><span> </span></span></p><div data-hook="rcv-block5" type="paragraph"></div><p class="xVISr Y9Dpf bCMSCT OZy-3 lnyWN yMZv8w bCMSCT public-DraftStyleDefault-block-depth0 fixed-tab-size public-DraftStyleDefau ...

# %%
article.text
# Out:
# 'Joe Baldwin, UCTechMay 17, 20204 min readEnglish, A Frankenstein Monster of a Language English is a weird language. Any student who has had to memorize strange spelling anomalies or had to read aloud in class only to trip over a word with two different meanings and entirely different pronunciations can attest to this. For example, though they masquerade as the same word, lead (as in leader) and lead (as in the element) sound different when spoken. Taken to the extreme, sentences like “Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo” make complete grammatical sense. And, perhaps, consider that English is one of the only European languages in which nouns are not assigned gender.  There is a reason for these idiosyncrasies, though. The short answer is that English is a mutt of a language cobbled together from no less than four other languages. The long answer, however, requires a bit of history. First off, if you have ever been in a science class, then you are probably familiar with words like photosynthesis or Yttrium. You may already know that both words have Latin roots, but what you may not be aware of is how English acquired these words. Back in ye olden days when the Romans ruled England, they brought their customs with them. You might guess that this includes their language, but that is not entirely true. Latin never really took off in England. What did, however, was Christianity, which hung around England long after the Romans left. Christianity is important, because back in ye olden days, Latin was the language of the Church. And since in the Medieval era, authors tended to be from the Church, Latin became an integral part of literature. Not only were the clergy writing books, but being the most educated people of the day, these men would go on to study science (or what counted as science at the time). Likewise, clergymen became architects, mathematicians, teachers, etc. So when these men wrote down their notes or lessons or instructions, it was in Latin. In the centuries following, men of science would study the notes of their predecessors, and to keep things consistent, they adopted Latin when naming things. This is where English gets words like herbivore, agriculture, aqueducts, multiply, etc. Roman rule didn’t last forever in Britain. In the early 400s C.E., Romans left the island forever, allowing other peoples to conquer it. Enter Jutes, Saxons, and Angles, who crossed the channel at some point in the 500s and quickly conquered the island of Britain. These peoples settled the land, married each other, and created a new culture called Anglo-Saxon. Their languages fused together into what we call Old-English. They didn’t say they spoke Old-English; rather they spoke Anglish (referring to their homeland “of the Angles”). And where did these people speak Anglish? In Angleland of course, where they drank beer with their friends in their homes, after a hearty welcome. On Wednesday, Thursday, or Friday, an Anglo-Saxon would take care of his cows, sheep, and swines in the barn. All of these new words would become mainstays of the English language. But that would not be the last time a conquering people would forever change English. In the late 700s C.E., a new group of people came to stay--Vikings. Much like the Anglo-Saxons, Vikings conquered areas of England and brought their culture with them. Of course, this includes their favorite pastimes. You know: slaughtering people by putting their axes in their victims’ skulls, outside of cottage windows. These words may sound ugly, but remember, the Vikings were a people of give and take, and at least they were happy with their husbands and sisters. With new people come new words that join the ranks of English vocabulary. Lastly, in 1066, the Normans under William the Conqueror (well, you can guess) conquered England. You can probably predict what happens next. Except this time, it is a little different. William had just taken over a large kingdom and he needed ...

# %%
image_url = article.find_all('img')[0].get('data-pin-media')
# Out:
# 'https://static.wixstatic.com/media/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png/v1/fill/w_960,h_540,al_c,q_90/0089f9_e01e6a6db883427ea928ae3d6587f87d~mv2.png'

# %%
title = article.find('h1').text
title
# Out:
# 'English, A Frankenstein Monster of a Language'

# %%
text_list = [a.text for a in article.find_all('p')]

text = '\n'.join(text_list)
text
# Out:
# ' \nEnglish is a weird language. Any student who has had to memorize strange spelling anomalies or had to read aloud in class only to trip over a word with two different meanings and entirely different pronunciations can attest to this. For example, though they masquerade as the same word, lead (as in leader) and lead (as in the element) sound different when spoken. Taken to the extreme, sentences like “Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo” make complete grammatical sense. And, perhaps, consider that English is one of the only European languages in which nouns are not assigned gender. \n \nThere is a reason for these idiosyncrasies, though. The short answer is that English is a mutt of a language cobbled together from no less than four other languages. The long answer, however, requires a bit of history.\n \nFirst off, if you have ever been in a science class, then you are probably familiar with words like photosynthesis or Yttrium. You may already know that both words have Latin roots, but what you may not be aware of is how English acquired these words. Back in ye olden days when the Romans ruled England, they brought their customs with them. You might guess that this includes their language, but that is not entirely true. Latin never really took off in England. What did, however, was Christianity, which hung around England long after the Romans left. Christianity is important, because back in ye olden days, Latin was the language of the Church. And since in the Medieval era, authors tended to be from the Church, Latin became an integral part of literature. Not only were the clergy writing books, but being the most educated people of the day, these men would go on to study science (or what counted as science at the time). Likewise, clergymen became architects, mathematicians, teachers, etc. So when these men wrote down their notes or lessons or instructions, it was in Latin. In the centuries following, men of science would study the notes of their predecessors, and to keep things consistent, they adopted Latin when naming things. This is where English gets words like herbivore, agriculture, aqueducts, multiply, etc.\n \nRoman rule didn’t last forever in Britain. In the early 400s C.E., Romans left the island forever, allowing other peoples to conquer it. Enter Jutes, Saxons, and Angles, who crossed the channel at some point in the 500s and quickly conquered the island of Britain. These peoples settled the land, married each other, and created a new culture called Anglo-Saxon. Their languages fused together into what we call Old-English. They didn’t say they spoke Old-English; rather they spoke Anglish (referring to their homeland “of the Angles”). And where did these people speak Anglish? In Angleland of course, where they drank beer with their friends in their homes, after a hearty welcome. On Wednesday, Thursday, or Friday, an Anglo-Saxon would take care of his cows, sheep, and swines in the barn. All of these new words would become mainstays of the English language.\n \nBut that would not be the last time a conquering people would forever change English. In the late 700s C.E., a new group of people came to stay--Vikings. Much like the Anglo-Saxons, Vikings conquered areas of England and brought their culture with them. Of course, this includes their favorite pastimes. You know: slaughtering people by putting their axes in their victims’ skulls, outside of cottage windows. These words may sound ugly, but remember, the Vikings were a people of give and take, and at least they were happy with their husbands and sisters. With new people come new words that join the ranks of English vocabulary.\n \nLastly, in 1066, the Normans under William the Conqueror (well, you can guess) conquered England. You can probably predict what happens next. Except this time, it is a little different. William had just taken over a large kingdom and he needed people to run it. William didn’t trust the local Anglo-Saxons a ...

# %%
meta_data = [a.text for a in article.find_all('li')]
full_name = meta_data[0].split(',')[0]
school = meta_data[0].split(',')[1]
short_name = full_name.split(' ')[0].lower()
date = meta_data[3]
category = meta_data[-1]

# %%
article = f"""---
layout: post
title:  "{title}"
author: {short_name}
categories: [ {category} ]
image: assets/images/3.jpg
---

{text}

"""
article
# Out:
# '---\nlayout: post\ntitle:  "English, A Frankenstein Monster of a Language"\nauthor: joe\ncategories: [ News ]\nimage: assets/images/3.jpg\n---\n\n \nEnglish is a weird language. Any student who has had to memorize strange spelling anomalies or had to read aloud in class only to trip over a word with two different meanings and entirely different pronunciations can attest to this. For example, though they masquerade as the same word, lead (as in leader) and lead (as in the element) sound different when spoken. Taken to the extreme, sentences like “Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo” make complete grammatical sense. And, perhaps, consider that English is one of the only European languages in which nouns are not assigned gender. \n \nThere is a reason for these idiosyncrasies, though. The short answer is that English is a mutt of a language cobbled together from no less than four other languages. The long answer, however, requires a bit of history.\n \nFirst off, if you have ever been in a science class, then you are probably familiar with words like photosynthesis or Yttrium. You may already know that both words have Latin roots, but what you may not be aware of is how English acquired these words. Back in ye olden days when the Romans ruled England, they brought their customs with them. You might guess that this includes their language, but that is not entirely true. Latin never really took off in England. What did, however, was Christianity, which hung around England long after the Romans left. Christianity is important, because back in ye olden days, Latin was the language of the Church. And since in the Medieval era, authors tended to be from the Church, Latin became an integral part of literature. Not only were the clergy writing books, but being the most educated people of the day, these men would go on to study science (or what counted as science at the time). Likewise, clergymen became architects, mathematicians, teachers, etc. So when these men wrote down their notes or lessons or instructions, it was in Latin. In the centuries following, men of science would study the notes of their predecessors, and to keep things consistent, they adopted Latin when naming things. This is where English gets words like herbivore, agriculture, aqueducts, multiply, etc.\n \nRoman rule didn’t last forever in Britain. In the early 400s C.E., Romans left the island forever, allowing other peoples to conquer it. Enter Jutes, Saxons, and Angles, who crossed the channel at some point in the 500s and quickly conquered the island of Britain. These peoples settled the land, married each other, and created a new culture called Anglo-Saxon. Their languages fused together into what we call Old-English. They didn’t say they spoke Old-English; rather they spoke Anglish (referring to their homeland “of the Angles”). And where did these people speak Anglish? In Angleland of course, where they drank beer with their friends in their homes, after a hearty welcome. On Wednesday, Thursday, or Friday, an Anglo-Saxon would take care of his cows, sheep, and swines in the barn. All of these new words would become mainstays of the English language.\n \nBut that would not be the last time a conquering people would forever change English. In the late 700s C.E., a new group of people came to stay--Vikings. Much like the Anglo-Saxons, Vikings conquered areas of England and brought their culture with them. Of course, this includes their favorite pastimes. You know: slaughtering people by putting their axes in their victims’ skulls, outside of cottage windows. These words may sound ugly, but remember, the Vikings were a people of give and take, and at least they were happy with their husbands and sisters. With new people come new words that join the ranks of English vocabulary.\n \nLastly, in 1066, the Normans under William the Conqueror (well, you can guess) conquered England. You can probably predict what happens next. Except this time, i ...

# %%
for key, value in authors.items():
    print(value[-1], file=open("authors.txt", "a"))

# %%
authors = {'akash': ['Akash Dubey', 'AIT'],
 'alan': ['Alan Ostrovsky',
  ' AIT',
  '    alan:\n      name:           Alan Ostrovsky\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg   role:           Member\n      bio:            "Hi, I am Alan Ostrovsky!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'joe': ['Joe Baldwin',
  ' UCTech',
  '    joe:\n      name:           Joe Baldwin\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Joe Baldwin!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'omolola': ['Omolola Falana',
  ' MHS',
  '    omolola:\n      name:           Omolola Falana\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Omolola Falana!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'haralambos': ['Haralambos Liberatos',
  ' UCTech',
  '    haralambos:\n      name:           Haralambos Liberatos\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Haralambos Liberatos!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'victoria': ['Victoria Gee',
  ' MHS',
  '    victoria:\n      name:           Victoria Gee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Victoria Gee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'laura': ['Laura Felder',
  ' UCTech',
  '    laura:\n      name:           Laura Felder\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Laura Felder!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'rebecca': ['Rebecca Lee',
  'AIT',
  '    rebecca:\n      name:           Rebecca Lee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Rebecca Lee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         AIT\n      grade:          Alumni'],
 '': [' Sara Schwartz',
  ' AAHS',
  '    :\n      name:            Sara Schwartz\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am  Sara Schwartz!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'audrey': ['Audrey Miller',
  ' UCTech',
  '    audrey:\n      name:           Audrey Miller\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Audrey Miller!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'natalie': ['Natalie Lee',
  ' MHS',
  '    natalie:\n      name:           Natalie Lee\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Natalie Lee!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'dylan': ['Dylan Intwala',
  ' AIT',
  '    dylan:\n      name:           Dylan Intwala\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Dylan Intwala!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'alondra': ['Alondra Martinez',
  ' UCTech',
  '    alondra:\n      name:           Alondra Martinez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Alondra Martinez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'ernest': ['Ernest Romero',
  ' APA',
  '    ernest:\n      name:           Ernest Romero\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Ernest Romero!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
 'gregory': ['Gregory Martinez',
  ' AAHS',
  '    gregory:\n      name:           Gregory Martinez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Gregory Martinez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'maya': ['Maya Dias',
  ' AIT',
  '    maya:\n      name:           Maya Dias\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Maya Dias!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'shreya': ['Shreya Nara',
  ' AIT',
  '    shreya:\n      name:           Shreya Nara\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Shreya Nara!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'ella': ['Ella Platts',
  ' UCTech',
  '    ella:\n      name:           Ella Platts\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Ella Platts!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'monica': ['Monica Manescu',
  ' AAHS',
  '    monica:\n      name:           Monica Manescu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Monica Manescu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'diya': ['Diya Nainwal',
  ' AAHS',
  '    diya:\n      name:           Diya Nainwal\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Diya Nainwal!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'kenna': ['Kenna Srivastava',
  ' MHS',
  '    kenna:\n      name:           Kenna Srivastava\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Kenna Srivastava!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'saniya': ['Saniya Harlalka',
  ' AAHS',
  '    saniya:\n      name:           Saniya Harlalka\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Saniya Harlalka!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'justin': ['Justin Zimmerman',
  ' AIT',
  '    justin:\n      name:           Justin Zimmerman\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Justin Zimmerman!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'sarah': ['Sarah Bauman',
  ' APA',
  '    sarah:\n      name:           Sarah Bauman\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Sarah Bauman!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
 'kaitlyn': ['Kaitlyn Landaverde',
  ' APA',
  '    kaitlyn:\n      name:           Kaitlyn Landaverde\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Kaitlyn Landaverde!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
 'mattia': ['Mattia Leingang',
  ' AIT',
  '    mattia:\n      name:           Mattia Leingang\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Mattia Leingang!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'eric': ['Eric Yu',
  ' AIT',
  '    eric:\n      name:           Eric Yu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Eric Yu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'megan': ['Megan Lahetta',
  ' UCTech',
  '    megan:\n      name:           Megan Lahetta\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Megan Lahetta!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'daivya': ['Daivya Sadhvani',
  ' AIT',
  '    daivya:\n      name:           Daivya Sadhvani\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Daivya Sadhvani!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'jaime': ['Jaime Paladi',
  ' AIT',
  '    jaime:\n      name:           Jaime Paladi\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Jaime Paladi!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'akwele': ['Akwele Lokko',
  ' AAHS',
  '    akwele:\n      name:           Akwele Lokko\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Akwele Lokko!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'patrick': ['Patrick Mochnal',
  ' AIT',
  '    patrick:\n      name:           Patrick Mochnal\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Patrick Mochnal!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'haley': ['Haley Richardson',
  ' UCTech',
  '    haley:\n      name:           Haley Richardson\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Haley Richardson!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni'],
 'anusha': ['Anusha Iyer',
  ' AIT',
  '    anusha:\n      name:           Anusha Iyer\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Anusha Iyer!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'chloe': ['Chloe Gavula',
  ' APA',
  '    chloe:\n      name:           Chloe Gavula\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Chloe Gavula!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
 'sara': ['Sara Schwartz',
  ' AAHS',
  '    sara:\n      name:           Sara Schwartz\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Sara Schwartz!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'ahmad': ['Ahmad Khizar',
  ' AAHS',
  '    ahmad:\n      name:           Ahmad Khizar\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Ahmad Khizar!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AAHS\n      grade:          Alumni'],
 'ana': ['Ana Obradovic',
  ' AIT',
  '    ana:\n      name:           Ana Obradovic\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Ana Obradovic!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'rachel': ['Rachel Bataille',
  ' MHS',
  '    rachel:\n      name:           Rachel Bataille\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Rachel Bataille!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'lilly': ['Lilly Resnick',
  'AIT',
  '    lilly:\n      name:           Lilly Resnick\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Lilly Resnick!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         AIT\n      grade:          Alumni'],
 'ivy': ['Ivy Liu',
  ' MHS',
  '    ivy:\n      name:           Ivy Liu\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Ivy Liu!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          MHS\n      grade:          Alumni'],
 'anonymous': ['Anonymous',
  'Unknown',
  '    anonymous:\n      name:           Anonymous\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Anonymous!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:         Unknown\n      grade:          Alumni'],
 'sophia': ['Sophia Mekbeb',
  ' APA',
  '    sophia:\n      name:           Sophia Mekbeb\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Sophia Mekbeb!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          APA\n      grade:          Alumni'],
 'mila': ['Mila Talati',
  ' AIT',
  '    mila:\n      name:           Mila Talati\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Mila Talati!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          AIT\n      grade:          Alumni'],
 'gissele': ['Gissele Hernandez',
  ' UCTech',
  '    gissele:\n      name:           Gissele Hernandez\n      site:           https://www.wowthemes.net\n      avatar:         /assets/images/anonymous.jpg
      role:           Member\n      bio:            "Hi, I am Gissele Hernandez!"\n      email:          no_reply@ucvts.org\n      twitter:        https://twitter.com/\n      school:          UCTech\n      grade:          Alumni']}

# %%
# Generate individual author pages from authors dictionary
for short, value in authors.items():
    # Read template file
    with open('_pages/author-sal.html', 'r') as f:
        template = f.read()

    template = template.replace('akash-dubey', value[0].lower().replace(" ", "-"))
    
    # Replace akash with short
    template = template.replace('akash', short)

    # Replace Akash with value[0]
    template = template.replace('Akash', value[0])

    # save new file
    with open('_pages/author-' + short + '.html', 'w') as f:
        f.write(template)
